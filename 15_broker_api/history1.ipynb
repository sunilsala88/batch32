# %% [markdown]
# crypto

# %%
from alpaca.data.historical.crypto import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit
import pendulum as dt
timez_zone="America/New_York"


crypto_historical_data_client = CryptoHistoricalDataClient()
req = CryptoBarsRequest(
    symbol_or_symbols = 'ETH/USD',
    timeframe=TimeFrame(amount = 15, unit = TimeFrameUnit.Minute), # specify timeframe
    start = dt.datetime(2024,1,1,1,1,1,tz=timez_zone),                          # specify start datetime, default=the beginning of the current day.
    end=dt.datetime(2024,1,25,1,1,1,tz=timez_zone),                                        # specify end datetime, default=now
    # limit = 2,                                               # specify limit
)

history_df2=crypto_historical_data_client.get_crypto_bars(req).df
history_df2
# Out:
#                                         open       high        low      close  \
# symbol  timestamp
# ETH/USD 2024-01-01 06:15:00+00:00  2275.1445  2279.2405  2274.5800  2275.6900
#         2024-01-01 06:30:00+00:00  2276.5230  2281.8500  2276.5230  2281.2050
#         2024-01-01 06:45:00+00:00  2282.3000  2282.6970  2281.1085  2281.4650
#         2024-01-01 07:00:00+00:00  2282.4910  2286.2960  2282.4910  2284.0885
#         2024-01-01 07:15:00+00:00  2283.3000  2285.5780  2282.6800  2285.3500
# ...                                      ...        ...        ...        ...
#         2024-01-25 05:00:00+00:00  2211.5280  2212.4845  2204.2700  2206.5685
#         2024-01-25 05:15:00+00:00  2205.7125  2209.2850  2202.3650  2205.8860
#         2024-01-25 05:30:00+00:00  2205.2500  2209.0350  2205.0020  2207.4450
#         2024-01-25 05:45:00+00:00  2208.0935  2211.1065  2208.0935  2210.8200
#         2024-01-25 06:00:00+00:00  2209.7050  2215.6500  2209.7050  2214.6550
#
#                                      volume  trade_count         vwap
# symbol  timestamp
# ETH/USD 2024-01-01 06:15:00+00:00  0.000000          0.0     0.000000
#         2024-01-01 06:30:00+00:00  0.437800          1.0  2278.470000
#         2024-01-01 06:45:00+00:00  0.000436          1.0  2282.300000
#         2024-01-01 07:00:00+00:00  0.000000          0.0     0.000000
#         2024-01-01 07:15:00+00:00  0.000000          0.0     0.000000
# ...                                     ...          ...          ...
#         2024-01-25 05:00:00+00:00  4.998000          3.0  2204.565174
#         2024-01-25 05:15:00+00:00  0.000000          0.0     0.000000
#         2024-01-25 05:30:00+00:00  0.133199          2.0  2207.357289
#         2024-01-25 05:45:00+00:00  0.176552          2.0  2210.199774
#         2024-01-25 06:00:00+00:00  0.000000          0.0     0.000000
#
# [2304 rows x 7 columns]

# %%
from alpaca.data.historical.stock import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit
import pendulum as dt
api_key='PKCGQ99MC5FQA1P8ZSRE'
secret_key='rkWLI1F2poiTbuERdzozfOLgVV6mrFKTH27Ugvb1'
shdc=StockHistoricalDataClient(api_key,secret_key)
req=StockBarsRequest(symbol_or_symbols='NVDA',
                    timeframe=TimeFrame(amount = 1, unit = TimeFrameUnit.Minute),
                    start = dt.datetime(2024,1,1,1,1,1,tz=timez_zone),                          # specify start datetime, default=the beginning of the current day.
                    end=dt.datetime(2025,1,25,1,1,1,tz=timez_zone),   
                     
                     )

data=shdc.get_stock_bars(req).df
data
# Out:
#                                       open    high     low     close   volume  \
# symbol timestamp
# NVDA   2024-01-02 09:00:00+00:00  493.7400  495.20  493.74  494.7200   2295.0
#        2024-01-02 09:01:00+00:00  494.8500  494.85  494.83  494.8300    726.0
#        2024-01-02 09:02:00+00:00  495.2500  495.25  494.95  495.2200   1008.0
#        2024-01-02 09:03:00+00:00  495.2800  495.28  495.28  495.2800    325.0
#        2024-01-02 09:04:00+00:00  495.2800  495.28  495.28  495.2800    309.0
# ...                                    ...     ...     ...       ...      ...
#        2025-01-25 00:55:00+00:00  142.1100  142.13  142.10  142.1300   9013.0
#        2025-01-25 00:56:00+00:00  142.1105  142.13  142.06  142.1200  22231.0
#        2025-01-25 00:57:00+00:00  142.1100  142.11  142.07  142.0700   7582.0
#        2025-01-25 00:58:00+00:00  142.0600  142.07  142.05  142.0599  22849.0
#        2025-01-25 00:59:00+00:00  142.0598  142.06  142.00  142.0200  30638.0
#
#                                   trade_count        vwap
# symbol timestamp
# NVDA   2024-01-02 09:00:00+00:00        101.0  494.818421
#        2024-01-02 09:01:00+00:00         40.0  494.836990
#        2024-01-02 09:02:00+00:00         24.0  495.171220
#        2024-01-02 09:03:00+00:00         18.0  495.280000
#        2024-01-02 09:04:00+00:00         18.0  495.280000
# ...                                       ...         ...
#        2025-01-25 00:55:00+00:00        104.0  142.124611
#        2025-01-25 00:56:00+00:00        157.0  142.100334
#        2025-01-25 00:57:00+00:00        118.0  142.085457
#        2025-01-25 00:58:00+00:00        155.0  142.062032
#        2025-01-25 00:59:00+00:00        388.0  142.022118
#
# [243478 rows x 7 columns]

# %%
data.reset_index().set_index('timestamp')[['open',	'high',	'low',	'close',	'volume']	]
# Out:
#                                open    high     low     close   volume
# timestamp
# 2024-01-02 09:00:00+00:00  493.7400  495.20  493.74  494.7200   2295.0
# 2024-01-02 09:01:00+00:00  494.8500  494.85  494.83  494.8300    726.0
# 2024-01-02 09:02:00+00:00  495.2500  495.25  494.95  495.2200   1008.0
# 2024-01-02 09:03:00+00:00  495.2800  495.28  495.28  495.2800    325.0
# 2024-01-02 09:04:00+00:00  495.2800  495.28  495.28  495.2800    309.0
# ...                             ...     ...     ...       ...      ...
# 2025-01-25 00:55:00+00:00  142.1100  142.13  142.10  142.1300   9013.0
# 2025-01-25 00:56:00+00:00  142.1105  142.13  142.06  142.1200  22231.0
# 2025-01-25 00:57:00+00:00  142.1100  142.11  142.07  142.0700   7582.0
# 2025-01-25 00:58:00+00:00  142.0600  142.07  142.05  142.0599  22849.0
# 2025-01-25 00:59:00+00:00  142.0598  142.06  142.00  142.0200  30638.0
#
# [243478 rows x 5 columns]

# %% [markdown]
# option

# %%
from alpaca.data.historical.option import OptionHistoricalDataClient
from alpaca.data.requests import OptionBarsRequest
from alpaca.data.timeframe import TimeFrame, TimeFrameUnit
import pendulum as dt
api_key='PKCGQ99MC5FQA1P8ZSRE'
secret_key='rkWLI1F2poiTbuERdzozfOLgVV6mrFKTH27Ugvb1'
ohdc=OptionHistoricalDataClient(api_key,secret_key)
req=OptionBarsRequest(symbol_or_symbols='SPY250811C00630000',
                    timeframe=TimeFrame(amount = 1, unit = TimeFrameUnit.Minute),
                    start = dt.datetime(2025,8,1,1,1,1,tz=timez_zone),                          # specify start datetime, default=the beginning of the current day.
                    end=dt.datetime(2025,8,8,1,1,1,tz=timez_zone),   
                     
                     )

data=ohdc.get_option_bars(req).df
data
# Out:
#                                               open  high   low  close  volume  \
# symbol             timestamp
# SPY250811C00630000 2025-08-01 13:30:00+00:00  4.13  4.13  3.90   3.90    11.0
#                    2025-08-01 13:31:00+00:00  3.88  3.92  3.88   3.89    30.0
#                    2025-08-01 13:32:00+00:00  3.80  3.80  3.60   3.60    46.0
#                    2025-08-01 13:33:00+00:00  3.65  3.66  3.65   3.65     8.0
#                    2025-08-01 13:34:00+00:00  3.59  3.59  3.57   3.57    38.0
# ...                                            ...   ...   ...    ...     ...
#                    2025-08-07 20:10:00+00:00  4.52  4.52  4.46   4.46    11.0
#                    2025-08-07 20:11:00+00:00  4.50  4.54  4.50   4.54     3.0
#                    2025-08-07 20:12:00+00:00  4.58  4.60  4.58   4.60     7.0
#                    2025-08-07 20:13:00+00:00  4.64  4.69  4.64   4.69    11.0
#                    2025-08-07 20:14:00+00:00  4.72  4.73  4.69   4.73    12.0
#
#                                               trade_count      vwap
# symbol             timestamp
# SPY250811C00630000 2025-08-01 13:30:00+00:00          4.0  4.004545
#                    2025-08-01 13:31:00+00:00          4.0  3.883000
#                    2025-08-01 13:32:00+00:00         10.0  3.738696
#                    2025-08-01 13:33:00+00:00          6.0  3.651250
#                    2025-08-01 13:34:00+00:00          6.0  3.583684
# ...                                                   ...       ...
#                    2025-08-07 20:10:00+00:00          7.0  4.489091
#                    2025-08-07 20:11:00+00:00          3.0  4.520000
#                    2025-08-07 20:12:00+00:00          4.0  4.590000
#                    2025-08-07 20:13:00+00:00          4.0  4.673636
#                    2025-08-07 20:14:00+00:00          6.0  4.711667
#
# [1333 rows x 7 columns]

# %%
from alpaca.trading.requests import GetOptionContractsRequest
from alpaca.trading.enums import AssetStatus
from alpaca.trading.client import TradingClient
# setup clients
trade_client = TradingClient(api_key=api_key, secret_key=secret_key)

# get list of options contracts for the given underlying symbol (e.g. SPY,AAPL)
# - get_option_contracts() is a new method to get list of options contracts
# - in this example, we get 2 options contracts for SPY,AAPL
# - you can continue to fetch options contracts by specifying page_token from next_page_token of response
underlying_symbols = ["SPY"]
req = GetOptionContractsRequest(
    underlying_symbols = underlying_symbols,               # specify underlying symbols
    status = AssetStatus.ACTIVE,                           # specify asset status: active (default)
    expiration_date = None,                                # specify expiration date (specified date + 1 day range)
    expiration_date_gte = None,                            # we can pass date object
    expiration_date_lte = None,                            # or string (YYYY-MM-DD)
    root_symbol = None,                                    # specify root symbol
    type = None,                                           # specify option type (ContractType.CALL or ContractType.PUT)
    style = None,                                          # specify option style (ContractStyle.AMERICAN or ContractStyle.EUROPEAN)
    strike_price_gte = None,                               # specify strike price range
    strike_price_lte = None,                               # specify strike price range
    # limit = 2,                                             # specify limit
    page_token = None,                                     # specify page token
)
res = trade_client.get_option_contracts(req)
res
# Out:
# {   'next_page_token': 'MTAw',
#     'option_contracts': [   {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '73ae442d-2c7c-4925-818e-d8d0b2bea60e',
#                                 'name': 'SPY Aug 11 2025 400 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 400.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00400000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'f7dc0d25-ce4b-40a8-acae-6052ca2e4f72',
#                                 'name': 'SPY Aug 11 2025 405 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 405.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00405000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '99362a19-6111-401c-8cd9-40ac775dd6a9',
#                                 'name': 'SPY Aug 11 2025 410 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 410.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00410000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '4dc7505e-02c7-4e89-bad0-6eb88852ef81',
#                                 'name': 'SPY Aug 11 2025 415 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 415.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00415000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '8baf3898-3bde-4dba-8d99-0a58620c6b77',
#                                 'name': 'SPY Aug 11 2025 420 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 420.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00420000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'ace4952d-df4c-4d70-a9d7-337620034f1a',
#                                 'name': 'SPY Aug 11 2025 425 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 425.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00425000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'df2d6cfb-955c-4281-8557-2e55f498ac6f',
#                                 'name': 'SPY Aug 11 2025 430 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 430.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00430000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '5e400838-bcf3-4d41-8d26-c6186fdcd72a',
#                                 'name': 'SPY Aug 11 2025 435 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 435.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00435000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'ea664dac-9fdb-4788-8506-9f0412d3d546',
#                                 'name': 'SPY Aug 11 2025 440 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 440.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00440000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'f440c7fd-94ae-47f7-a729-28c6e4d9d1f3',
#                                 'name': 'SPY Aug 11 2025 445 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 445.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00445000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'a6ddecf2-232d-441e-877d-cd03d1dca272',
#                                 'name': 'SPY Aug 11 2025 450 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 450.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00450000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '61b11dd5-3e3a-46fa-8dc5-03a7264a8103',
#                                 'name': 'SPY Aug 11 2025 455 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 455.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00455000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '80392f25-81ea-42fc-a9aa-c5cfc47cc293',
#                                 'name': 'SPY Aug 11 2025 460 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 460.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00460000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'cecc1ec4-6801-47b7-9287-9c49e5023ccf',
#                                 'name': 'SPY Aug 11 2025 465 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 465.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00465000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'd2faaf73-25db-4c4a-81bb-f29654d362d5',
#                                 'name': 'SPY Aug 11 2025 470 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 470.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00470000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'dc0399d3-a672-492a-b9e4-56ec54113e1e',
#                                 'name': 'SPY Aug 11 2025 475 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 475.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00475000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '973a3e30-d59a-4f9e-917d-f047b23ccd70',
#                                 'name': 'SPY Aug 11 2025 480 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 480.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00480000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '01da9fd8-2a9f-4897-8fcf-a65b72d3cac6',
#                                 'name': 'SPY Aug 11 2025 485 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 485.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00485000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '409b9505-bb33-4b33-88d9-7f164bce347d',
#                                 'name': 'SPY Aug 11 2025 490 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 490.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00490000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '09159eae-ec72-43db-a744-aa513509c9cc',
#                                 'name': 'SPY Aug 11 2025 495 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 495.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00495000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '133',
#                                 'close_price_date': datetime.date(2025, 8, 7),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'c8ac32c2-7538-4c49-adb7-a4075010b4b2',
#                                 'name': 'SPY Aug 11 2025 500 Call',
#                                 'open_interest': '15',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 500.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00500000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '956fc684-6915-4af9-8301-e143752bcd9c',
#                                 'name': 'SPY Aug 11 2025 505 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 505.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00505000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '172e8687-ef2e-48da-8ada-dd54d207340f',
#                                 'name': 'SPY Aug 11 2025 510 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 510.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00510000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '6bbffe60-8855-4e2f-a27e-01e3527439d9',
#                                 'name': 'SPY Aug 11 2025 515 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 515.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00515000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '43368aab-4adf-49f9-9726-879be63a8561',
#                                 'name': 'SPY Aug 11 2025 520 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 520.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00520000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '322ff273-7e09-499d-9929-bbf9cbe11fbc',
#                                 'name': 'SPY Aug 11 2025 525 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 525.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00525000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'dfb93c78-9141-420c-9a41-63036257ba4a',
#                                 'name': 'SPY Aug 11 2025 530 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 530.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00530000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '97.53',
#                                 'close_price_date': datetime.date(2025, 8, 6),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'fa068378-2d6c-43e5-b5bf-e5df1b416baf',
#                                 'name': 'SPY Aug 11 2025 535 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 535.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00535000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '832deb10-91d9-4d6b-805b-97b73eb591f0',
#                                 'name': 'SPY Aug 11 2025 540 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 540.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00540000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '63d0efc4-831d-47fa-b8a0-bd0faa0c0b72',
#                                 'name': 'SPY Aug 11 2025 545 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 545.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00545000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '79.99',
#                                 'close_price_date': datetime.date(2025, 8, 7),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'cc262477-9ae2-4b0e-8553-c07fc2bf0781',
#                                 'name': 'SPY Aug 11 2025 550 Call',
#                                 'open_interest': '2',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 550.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00550000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': None,
#                                 'close_price_date': None,
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '9ea9946f-08ec-4571-b465-0c92a8c4eba3',
#                                 'name': 'SPY Aug 11 2025 555 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 555.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00555000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '76.15',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '908c2aac-2a88-4df0-b54f-beb64d1b9c2e',
#                                 'name': 'SPY Aug 11 2025 560 Call',
#                                 'open_interest': '20',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 560.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00560000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '71.39',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '0e5ca5bf-4f9f-474b-8571-3374ae066ba9',
#                                 'name': 'SPY Aug 11 2025 565 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 565.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00565000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '66.11',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '5fdc87ce-defe-4d44-826e-8c0e4d476499',
#                                 'name': 'SPY Aug 11 2025 570 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 570.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00570000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '62.06',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '94f32f7b-dcec-446f-a9f7-78c1afbaf08c',
#                                 'name': 'SPY Aug 11 2025 575 Call',
#                                 'open_interest': None,
#                                 'open_interest_date': None,
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 575.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00575000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '46.88',
#                                 'close_price_date': datetime.date(2025, 8, 4),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'ffd44712-9c9f-4a7a-8f1a-d7f2df2a005b',
#                                 'name': 'SPY Aug 11 2025 580 Call',
#                                 'open_interest': '2',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 580.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00580000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '51.86',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '58b15acf-6917-446b-bbeb-e8164b78394a',
#                                 'name': 'SPY Aug 11 2025 585 Call',
#                                 'open_interest': '1',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 585.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00585000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '40.42',
#                                 'close_price_date': datetime.date(2025, 8, 6),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'cb407b41-7ad4-4540-935d-24a4912aedd3',
#                                 'name': 'SPY Aug 11 2025 590 Call',
#                                 'open_interest': '23',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 590.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00590000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '42.4',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'f398189d-e588-4eb0-a43c-dcf03e18b22f',
#                                 'name': 'SPY Aug 11 2025 595 Call',
#                                 'open_interest': '9',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 595.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00595000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '37.19',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '013f11d6-f411-49b7-b707-80206120a157',
#                                 'name': 'SPY Aug 11 2025 600 Call',
#                                 'open_interest': '6',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 600.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00600000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '32.88',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '4c8150c0-5593-4bcd-9c2b-21c03de86340',
#                                 'name': 'SPY Aug 11 2025 605 Call',
#                                 'open_interest': '13',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 605.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00605000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '24.88',
#                                 'close_price_date': datetime.date(2025, 8, 7),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '66144e8f-765a-45e9-8d29-79ffce179c17',
#                                 'name': 'SPY Aug 11 2025 608 Call',
#                                 'open_interest': '33',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 608.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00608000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
# ...
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'c769f674-765b-4e65-b82f-014ad214d1f6',
#                                 'name': 'SPY Aug 11 2025 652 Call',
#                                 'open_interest': '136',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 652.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00652000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.02',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '91d7f2d7-33f9-46fa-8df3-f11368ec0c7e',
#                                 'name': 'SPY Aug 11 2025 653 Call',
#                                 'open_interest': '268',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 653.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00653000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '1315feec-b710-4adc-bfca-0ea940fba488',
#                                 'name': 'SPY Aug 11 2025 654 Call',
#                                 'open_interest': '630',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 654.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00654000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '5498dce5-e8af-4f39-9ae5-929cd200483d',
#                                 'name': 'SPY Aug 11 2025 655 Call',
#                                 'open_interest': '6075',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 655.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00655000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '99e2e518-d17e-4bd8-a882-489f644b908d',
#                                 'name': 'SPY Aug 11 2025 656 Call',
#                                 'open_interest': '129',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 656.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00656000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'ee47a4b8-c206-41ea-adbc-8a1944b6b602',
#                                 'name': 'SPY Aug 11 2025 657 Call',
#                                 'open_interest': '313',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 657.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00657000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 7),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'b089b382-460f-4b67-8030-18af63918a8c',
#                                 'name': 'SPY Aug 11 2025 658 Call',
#                                 'open_interest': '1489',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 658.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00658000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 7),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '88775b97-276a-4d93-b83c-f6f8d4f4cf1d',
#                                 'name': 'SPY Aug 11 2025 659 Call',
#                                 'open_interest': '1612',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 659.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00659000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '3ddab447-6a61-4842-aec1-80b7290d485e',
#                                 'name': 'SPY Aug 11 2025 660 Call',
#                                 'open_interest': '410',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 660.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00660000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'b10ffca5-f34b-4795-9298-3bcb4ff74857',
#                                 'name': 'SPY Aug 11 2025 665 Call',
#                                 'open_interest': '630',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 665.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00665000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 7),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'fcd66d8d-0502-494f-85f9-8e0d98ad4e89',
#                                 'name': 'SPY Aug 11 2025 670 Call',
#                                 'open_interest': '69',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 670.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00670000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 1),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': 'ec8c7959-a055-4a30-a402-15f686d35070',
#                                 'name': 'SPY Aug 11 2025 675 Call',
#                                 'open_interest': '70',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 675.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00675000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 7),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '4affca85-1fdc-45ff-9964-0dad27d9d76f',
#                                 'name': 'SPY Aug 11 2025 680 Call',
#                                 'open_interest': '4',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 680.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00680000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'},
#                             {   'close_price': '0.01',
#                                 'close_price_date': datetime.date(2025, 8, 8),
#                                 'expiration_date': datetime.date(2025, 8, 11),
#                                 'id': '6be00548-e88f-49f6-ac7b-2100e9afa850',
#                                 'name': 'SPY Aug 11 2025 685 Call',
#                                 'open_interest': '3',
#                                 'open_interest_date': datetime.date(2025, 8, 7),
#                                 'root_symbol': 'SPY',
#                                 'size': '100',
#                                 'status': <AssetStatus.ACTIVE: 'active'>,
#                                 'strike_price': 685.0,
#                                 'style': <ExerciseStyle.AMERICAN: 'american'>,
#                                 'symbol': 'SPY250811C00685000',
#                                 'tradable': True,
#                                 'type': <ContractType.CALL: 'call'>,
#                                 'underlying_asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                                 'underlying_symbol': 'SPY'}]}
